# %%
#dependencies
import pandas as pd
import numpy as np
import csv

# %%
folder = 'Desktop/Project1/Data/cleaned_data.csv'

# %%
#import data from combined csv
df = pd.read_csv('data/cleaned_data.csv')
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#            video_id trending_date  category_id              publish_time  \
# 0       2kyS6SvSYSE      17.14.11           22  2017-11-13T17:13:01.000Z
# 1       1ZAPwfrtAFY      17.14.11           24  2017-11-13T07:30:00.000Z
# 2       5qpjK5DgCt4      17.14.11           23  2017-11-12T19:05:24.000Z
# 3       puqaWrEC7tY      17.14.11           24  2017-11-13T11:00:04.000Z
# 4       d380meD0W0M      17.14.11           24  2017-11-12T18:01:41.000Z
# 5       gHZ1Qz0KiKM      17.14.11           28  2017-11-13T19:07:23.000Z
# 6       39idVpFF7NQ      17.14.11           24  2017-11-12T05:37:17.000Z
# 7       nc99ccSXST0      17.14.11           28  2017-11-12T21:50:37.000Z
# 8       jr9QtXwC9vc      17.14.11            1  2017-11-13T14:00:23.000Z
# 9       TUmyygCMMGA      17.14.11           25  2017-11-13T13:45:16.000Z
# 10      9wRQljFNDW8      17.14.11           17  2017-11-13T02:05:26.000Z
# 11      VifQlJit6A0      17.14.11           24  2017-11-13T03:00:00.000Z
# ...

# %%
#dataframes for each country
US = df.loc[df["Country Code"]=="US"]
MX = df.loc[df["Country Code"]=="MX"]
CA = df.loc[df["Country Code"]=="CA"]
RU = df.loc[df["Country Code"]=="RU"]
DE = df.loc[df["Country Code"]=="DE"]
FR = df.loc[df["Country Code"]=="FR"]
GB = df.loc[df["Country Code"]=="GB"]
IN = df.loc[df["Country Code"]=="IN"]
JP = df.loc[df["Country Code"]=="JP"]
KR = df.loc[df["Country Code"]=="KR"]

# %%
total_count = len(df["category_id"].unique())
total_count

# %%
#dataframes created to display country, video_id, and trending.

data_us = US.loc[:,["Country Code", "video_id", "trending"]]
#data_us
data_mx = MX.loc[:,["Country Code", "video_id", "trending"]]
#data_mx

data_ca = CA.loc[:,["Country Code", "video_id", "trending"]]
#data_ca

data_ru = RU.loc[:,["Country Code", "video_id", "trending"]]
#data_ru

data_de = DE.loc[:,["Country Code", "video_id", "trending"]]
#data_de

data_fr = FR.loc[:,["Country Code", "video_id", "trending"]]
#data_fr
 
data_gb = GB.loc[:,["Country Code", "video_id", "trending"]]
#data_gb

data_in = IN.loc[:,["Country Code", "video_id", "trending"]]
data_jp = JP.loc[:,["Country Code", "video_id", "trending"]]
#data_jp

data_kr = KR.loc[:,["Country Code", "video_id", "trending"]]
#data_kr
# Out:
# C:\Users\19803\Anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
