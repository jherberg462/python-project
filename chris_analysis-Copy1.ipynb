# %%
#dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import data from combined csv
df = pd.read_csv('data/combined_data.csv')
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#            video_id trending_date  category_id              publish_time  \
# 0       2kyS6SvSYSE      17.14.11           22  2017-11-13T17:13:01.000Z
# 1       1ZAPwfrtAFY      17.14.11           24  2017-11-13T07:30:00.000Z
# 2       5qpjK5DgCt4      17.14.11           23  2017-11-12T19:05:24.000Z
# 3       puqaWrEC7tY      17.14.11           24  2017-11-13T11:00:04.000Z
# 4       d380meD0W0M      17.14.11           24  2017-11-12T18:01:41.000Z
# 5       gHZ1Qz0KiKM      17.14.11           28  2017-11-13T19:07:23.000Z
# 6       39idVpFF7NQ      17.14.11           24  2017-11-12T05:37:17.000Z
# 7       nc99ccSXST0      17.14.11           28  2017-11-12T21:50:37.000Z
# 8       jr9QtXwC9vc      17.14.11            1  2017-11-13T14:00:23.000Z
# 9       TUmyygCMMGA      17.14.11           25  2017-11-13T13:45:16.000Z
# 10      9wRQljFNDW8      17.14.11           17  2017-11-13T02:05:26.000Z
# 11      VifQlJit6A0      17.14.11           24  2017-11-13T03:00:00.000Z
# 12      5E4ZBSInqUU      17.14.11           10  2017-11-13T17:00:00.000Z
# 13      GgVmn66oK_A      17.14.11           25  2017-11-12T14:00:00.000Z
# 14      TaTleo4cOs8      17.14.11           15  2017-11-12T18:30:01.000Z
# 15      kgaO45SyaO4      17.14.11           28  2017-11-13T20:09:58.000Z
# 16      ZAQs-ctOqXQ      17.14.11           23  2017-11-12T17:00:05.000Z
# 17      YVfyYrEmzgM      17.14.11           27  2017-11-13T16:00:07.000Z
# 18      eNSN6qet1kE      17.14.11           28  2017-11-13T15:30:17.000Z
# 19      B5HORANmzHw      17.14.11           27  2017-11-12T22:00:01.000Z
# 20      vU14JY3x81A      17.14.11           27  2017-11-13T14:00:03.000Z
# 21      6VhU_T463sU      17.14.11           28  2017-11-12T15:00:01.000Z
# 22      _-aDHxoblr4      17.14.11           27  2017-11-13T16:00:03.000Z
# 23      JBZTZZAcFTw      17.14.11           26  2017-11-12T16:00:01.000Z
# 24      lZ68j2J_GOM      17.14.11           23  2017-11-13T14:44:24.000Z
# 25      dRpNZV18N_g      17.14.11           24  2017-11-12T14:00:04.000Z
# 26      fcVjitaM3LY      17.14.11           28  2017-11-13T12:13:36.000Z
# 27      qeWvgZLz9yU      17.14.11           26  2017-11-13T16:00:03.000Z
# 28      iIxy3JN3-jc      17.14.11           25  2017-11-13T15:42:28.000Z
# 29      n30k5CwLhS4      17.14.11            1  2011-05-29T17:03:12.000Z
# ...             ...           ...          ...                       ...
# 375912  dWK5g_FNZ9I      18.14.06           24  2018-06-13T06:00:01.000Z
# 375913  D5slHtZSvjY      18.14.06           22  2018-06-13T03:47:20.000Z
# 375914  22kidqKpiks      18.14.06           20  2018-06-12T09:00:03.000Z
# 375915  C2Aw5HoDJX0      18.14.06            1  2018-06-13T00:00:01.000Z
# 375916  4_7810_88w8      18.14.06           23  2018-06-12T09:38:25.000Z
# 375917  q-QVlVjYznc      18.14.06           24  2018-06-12T13:00:09.000Z
# 375918  ckQpVlwY0Yk      18.14.06           24  2018-06-12T06:00:01.000Z
# 375919  Hc7uhpgYoFI      18.14.06           15  2018-06-11T09:32:33.000Z
# 375920  XYyjbKjZq9c      18.14.06           22  2018-06-12T11:09:15.000Z
# 375921  BAucj902N0A      18.14.06           25  2018-06-12T10:25:49.000Z
# 375922  Qo8TZhxrk6U      18.14.06           22  2018-06-12T12:00:03.000Z
# 375923  _NT4XstZ_8U      18.14.06           17  2018-06-12T08:26:58.000Z
# 375924  LbSU1_SG91w      18.14.06           10  2018-06-10T16:32:19.000Z
# 375925  29EWEWkWr9Y      18.14.06           25  2018-06-12T10:40:40.000Z
# 375926  3GlHZVWgNEY      18.14.06           24  2018-06-12T03:01:38.000Z
# 375927  Rfa57NYWU-w      18.14.06           22  2018-06-11T07:45:37.000Z
# 375928  ZWex15ZhDi0      18.14.06           24  2018-06-11T09:57:01.000Z
# 375929  U2MAT-AlamE      18.14.06            1  2018-06-12T09:54:50.000Z
# 375930  Qhe8yupOJPg      18.14.06           20  2018-06-12T07:34:11.000Z
# 375931  B1Jm5lBHLLc      18.14.06           22  2018-06-12T18:41:03.000Z
# 375932  wrVO0mWVLpU      18.14.06           24  2018-06-09T16:35:57.000Z
# 375933  uHHe9aGGppU      18.14.06           24  2018-06-12T09:00:11.000Z
# 375934  KY2co-NcGjk      18.14.06           17  2018-06-11T01:52:24.000Z
# 375935  xb-ODLumogw      18.14.06           24  2018-06-11T07:00:03.000Z
# 375936  7niLVY31miI      18.14.06           25  2018-06-13T07:51:46.000Z
# 375937  pj6YBBrO1sQ      18.14.06           24  2018-06-10T23:00:01.000Z
# 375938  _Ne9ER-jr20      18.14.06           24  2018-06-12T07:00:06.000Z
# 375939  xuOQq_fzEjk      18.14.06           25  2018-06-12T13:17:29.000Z
# 375940  uXvjxeg08eQ      18.14.06           22  2018-06-11T11:57:20.000Z
# 375941  C-bLqIftDY4      18.14.06           29  2018-06-10T20:00:01.000Z
#
#           views   likes  dislikes  comment_count  video_error_or_removed  \
# 0        748374   57527      2966          15954                   False
# 1       2418783   97185      6146          12703                   False
# 2       3191434  146033      5339           8181                   False
# 3        343168   10172       666           2146                   False
# 4       2095731  132235      1989          17518                   False
# 5        119180    9763       511           1434                   False
# 6       2103417   15993      2445           1970                   False
# 7        817732   23663       778           3432                   False
# 8        826059    3543       119            340                   False
# 9        256426   12654      1363           2368                   False
# 10        81377     655        25            177                   False
# 11       104578    1576       303           1279                   False
# 12       687582  114188      1333           8371                   False
# 13       544770    7848      1171           3981                   False
# 14       207532    7473       246           2120                   False
# 15        75752    9419        52           1230                   False
# 16       295639    8011       638           1256                   False
# 17        78044    5398        53            385                   False
# 18        97007   11963        36           2211                   False
# 19       223871    8421       191           1214                   False
# 20       115791    9586        75           2800                   False
# 21       224019    3585       138            208                   False
# 22       144418   11758        89           1014                   False
# 23       145921    1707       578            673                   False
# 24        33980    4884        52            234                   False
# 25       223077    8676       193           1392                   False
# 26        80705    4687        41            437                   False
# 27       120727    9033       224           1346                   False
# 28        27943     156        36             83                   False
# 29        50867     715       238            246                   False
# ...         ...     ...       ...            ...                     ...
# 375912    13175     205        10             59                   False
# 375913   224994    9898       330           8620                   False
# 375914   104821    1865        21            344                   False
# 375915    23404     190        29            111                   False
# 375916   114203    1660        65            417                   False
# 375917    79602    2123       101           1171                   False
# 375918   264256    1177        75            404                   False
# 375919    98485     963        29            371                   False
# 375920    20198    1059         5            201                   False
# 375921    63748    3228       119            589                   False
# 375922   175029    6399        34            681                   False
# 375923   267000    2910       113            857                   False
# 375924  2251851  159331       648          13263                   False
# 375925    59702     483        68            135                   False
# 375926    56355     315        37            143                   False
# 375927   285007       0         0            566                   False
# 375928    26003     180         5            145                   False
# 375929    52623    1347        34            428                   False
# 375930    62962    1375        15             93                   False
# 375931    26389    1989        42            233                   False
# 375932   250051   10006      6708              0                   False
# 375933   736406   12361      1527           1637                   False
# 375934    51232     761        12             92                   False
# 375935   159204     433        58            183                   False
# 375936    20923      86        11             18                   False
# 375937   156439     383        58            308                   False
# 375938   130948    3121        55            988                   False
# 375939    62555     319        71            105                   False
# 375940    63306    2369        27            571                   False
# 375941    63716     500        58            135                   False
#
#        Country Code
# 0                US
# 1                US
# 2                US
# 3                US
# 4                US
# 5                US
# 6                US
# 7                US
# 8                US
# 9                US
# 10               US
# 11               US
# 12               US
# 13               US
# 14               US
# 15               US
# 16               US
# 17               US
# 18               US
# 19               US
# 20               US
# 21               US
# 22               US
# 23               US
# 24               US
# 25               US
# 26               US
# 27               US
# 28               US
# 29               US
# ...             ...
# 375912           KR
# 375913           KR
# 375914           KR
# 375915           KR
# 375916           KR
# 375917           KR
# 375918           KR
# 375919           KR
# 375920           KR
# 375921           KR
# 375922           KR
# 375923           KR
# 375924           KR
# 375925           KR
# 375926           KR
# 375927           KR
# 375928           KR
# 375929           KR
# 375930           KR
# 375931           KR
# 375932           KR
# 375933           KR
# 375934           KR
# 375935           KR
# 375936           KR
# 375937           KR
# 375938           KR
# 375939           KR
# 375940           KR
# 375941           KR
#
# [375942 rows x 10 columns]

# %%
#talk to group about dropping the following video_id's
#'#NAME?', '#VALUE!'
df_id_drop = df.drop(df[df['video_id'] == '#NAME?'].index, inplace = True)
df_value_drop = df.drop(df[df['video_id'] == '#VALUE!'].index, inplace = True)

# %%
#talk to group about dropping the following video_id's
#when likes and dislikes == 0 or comment_count == 0 or video_error_or_removed == True

df_like_drop = df.drop(df[df['likes'] == 0].index, inplace = True)
df_dislikes_drop = df.drop(df[df['dislikes'] == 0].index, inplace = True)
df_comment_count_drop = df.drop(df[df['comment_count'] == 0].index, inplace = True)
df_video_error_or_removed = df.drop(df[df['video_error_or_removed'] == True].index, inplace = True)
df
# Out:
#            video_id trending_date  category_id              publish_time  \
# 0       2kyS6SvSYSE      17.14.11           22  2017-11-13T17:13:01.000Z
# 1       1ZAPwfrtAFY      17.14.11           24  2017-11-13T07:30:00.000Z
# 2       5qpjK5DgCt4      17.14.11           23  2017-11-12T19:05:24.000Z
# 3       puqaWrEC7tY      17.14.11           24  2017-11-13T11:00:04.000Z
# 4       d380meD0W0M      17.14.11           24  2017-11-12T18:01:41.000Z
# 5       gHZ1Qz0KiKM      17.14.11           28  2017-11-13T19:07:23.000Z
# 6       39idVpFF7NQ      17.14.11           24  2017-11-12T05:37:17.000Z
# 7       nc99ccSXST0      17.14.11           28  2017-11-12T21:50:37.000Z
# 8       jr9QtXwC9vc      17.14.11            1  2017-11-13T14:00:23.000Z
# 9       TUmyygCMMGA      17.14.11           25  2017-11-13T13:45:16.000Z
# 10      9wRQljFNDW8      17.14.11           17  2017-11-13T02:05:26.000Z
# 11      VifQlJit6A0      17.14.11           24  2017-11-13T03:00:00.000Z
# 12      5E4ZBSInqUU      17.14.11           10  2017-11-13T17:00:00.000Z
# 13      GgVmn66oK_A      17.14.11           25  2017-11-12T14:00:00.000Z
# 14      TaTleo4cOs8      17.14.11           15  2017-11-12T18:30:01.000Z
# 15      kgaO45SyaO4      17.14.11           28  2017-11-13T20:09:58.000Z
# 16      ZAQs-ctOqXQ      17.14.11           23  2017-11-12T17:00:05.000Z
# 17      YVfyYrEmzgM      17.14.11           27  2017-11-13T16:00:07.000Z
# 18      eNSN6qet1kE      17.14.11           28  2017-11-13T15:30:17.000Z
# 19      B5HORANmzHw      17.14.11           27  2017-11-12T22:00:01.000Z
# 20      vU14JY3x81A      17.14.11           27  2017-11-13T14:00:03.000Z
# 21      6VhU_T463sU      17.14.11           28  2017-11-12T15:00:01.000Z
# 22      _-aDHxoblr4      17.14.11           27  2017-11-13T16:00:03.000Z
# 23      JBZTZZAcFTw      17.14.11           26  2017-11-12T16:00:01.000Z
# 24      lZ68j2J_GOM      17.14.11           23  2017-11-13T14:44:24.000Z
# 25      dRpNZV18N_g      17.14.11           24  2017-11-12T14:00:04.000Z
# 26      fcVjitaM3LY      17.14.11           28  2017-11-13T12:13:36.000Z
# 27      qeWvgZLz9yU      17.14.11           26  2017-11-13T16:00:03.000Z
# 28      iIxy3JN3-jc      17.14.11           25  2017-11-13T15:42:28.000Z
# 29      n30k5CwLhS4      17.14.11            1  2011-05-29T17:03:12.000Z
# ...             ...           ...          ...                       ...
# 375910  vccDTOEKq30      18.14.06           24  2018-06-12T12:10:44.000Z
# 375911  eygDSQF_BQQ      18.14.06           25  2018-06-12T13:37:59.000Z
# 375912  dWK5g_FNZ9I      18.14.06           24  2018-06-13T06:00:01.000Z
# 375913  D5slHtZSvjY      18.14.06           22  2018-06-13T03:47:20.000Z
# 375914  22kidqKpiks      18.14.06           20  2018-06-12T09:00:03.000Z
# 375915  C2Aw5HoDJX0      18.14.06            1  2018-06-13T00:00:01.000Z
# 375916  4_7810_88w8      18.14.06           23  2018-06-12T09:38:25.000Z
# 375917  q-QVlVjYznc      18.14.06           24  2018-06-12T13:00:09.000Z
# 375918  ckQpVlwY0Yk      18.14.06           24  2018-06-12T06:00:01.000Z
# 375919  Hc7uhpgYoFI      18.14.06           15  2018-06-11T09:32:33.000Z
# 375920  XYyjbKjZq9c      18.14.06           22  2018-06-12T11:09:15.000Z
# 375921  BAucj902N0A      18.14.06           25  2018-06-12T10:25:49.000Z
# 375922  Qo8TZhxrk6U      18.14.06           22  2018-06-12T12:00:03.000Z
# 375923  _NT4XstZ_8U      18.14.06           17  2018-06-12T08:26:58.000Z
# 375924  LbSU1_SG91w      18.14.06           10  2018-06-10T16:32:19.000Z
# 375925  29EWEWkWr9Y      18.14.06           25  2018-06-12T10:40:40.000Z
# 375926  3GlHZVWgNEY      18.14.06           24  2018-06-12T03:01:38.000Z
# 375928  ZWex15ZhDi0      18.14.06           24  2018-06-11T09:57:01.000Z
# 375929  U2MAT-AlamE      18.14.06            1  2018-06-12T09:54:50.000Z
# 375930  Qhe8yupOJPg      18.14.06           20  2018-06-12T07:34:11.000Z
# 375931  B1Jm5lBHLLc      18.14.06           22  2018-06-12T18:41:03.000Z
# 375933  uHHe9aGGppU      18.14.06           24  2018-06-12T09:00:11.000Z
# 375934  KY2co-NcGjk      18.14.06           17  2018-06-11T01:52:24.000Z
# 375935  xb-ODLumogw      18.14.06           24  2018-06-11T07:00:03.000Z
# 375936  7niLVY31miI      18.14.06           25  2018-06-13T07:51:46.000Z
# 375937  pj6YBBrO1sQ      18.14.06           24  2018-06-10T23:00:01.000Z
# 375938  _Ne9ER-jr20      18.14.06           24  2018-06-12T07:00:06.000Z
# 375939  xuOQq_fzEjk      18.14.06           25  2018-06-12T13:17:29.000Z
# 375940  uXvjxeg08eQ      18.14.06           22  2018-06-11T11:57:20.000Z
# 375941  C-bLqIftDY4      18.14.06           29  2018-06-10T20:00:01.000Z
#
#           views   likes  dislikes  comment_count  video_error_or_removed  \
# 0        748374   57527      2966          15954                   False
# 1       2418783   97185      6146          12703                   False
# 2       3191434  146033      5339           8181                   False
# 3        343168   10172       666           2146                   False
# 4       2095731  132235      1989          17518                   False
# 5        119180    9763       511           1434                   False
# 6       2103417   15993      2445           1970                   False
# 7        817732   23663       778           3432                   False
# 8        826059    3543       119            340                   False
# 9        256426   12654      1363           2368                   False
# 10        81377     655        25            177                   False
# 11       104578    1576       303           1279                   False
# 12       687582  114188      1333           8371                   False
# 13       544770    7848      1171           3981                   False
# 14       207532    7473       246           2120                   False
# 15        75752    9419        52           1230                   False
# 16       295639    8011       638           1256                   False
# 17        78044    5398        53            385                   False
# 18        97007   11963        36           2211                   False
# 19       223871    8421       191           1214                   False
# 20       115791    9586        75           2800                   False
# 21       224019    3585       138            208                   False
# 22       144418   11758        89           1014                   False
# 23       145921    1707       578            673                   False
# 24        33980    4884        52            234                   False
# 25       223077    8676       193           1392                   False
# 26        80705    4687        41            437                   False
# 27       120727    9033       224           1346                   False
# 28        27943     156        36             83                   False
# 29        50867     715       238            246                   False
# ...         ...     ...       ...            ...                     ...
# 375910   211333    4092       108            667                   False
# 375911    17495     822        31             24                   False
# 375912    13175     205        10             59                   False
# 375913   224994    9898       330           8620                   False
# 375914   104821    1865        21            344                   False
# 375915    23404     190        29            111                   False
# 375916   114203    1660        65            417                   False
# 375917    79602    2123       101           1171                   False
# 375918   264256    1177        75            404                   False
# 375919    98485     963        29            371                   False
# 375920    20198    1059         5            201                   False
# 375921    63748    3228       119            589                   False
# 375922   175029    6399        34            681                   False
# 375923   267000    2910       113            857                   False
# 375924  2251851  159331       648          13263                   False
# 375925    59702     483        68            135                   False
# 375926    56355     315        37            143                   False
# 375928    26003     180         5            145                   False
# 375929    52623    1347        34            428                   False
# 375930    62962    1375        15             93                   False
# 375931    26389    1989        42            233                   False
# 375933   736406   12361      1527           1637                   False
# 375934    51232     761        12             92                   False
# 375935   159204     433        58            183                   False
# 375936    20923      86        11             18                   False
# 375937   156439     383        58            308                   False
# 375938   130948    3121        55            988                   False
# 375939    62555     319        71            105                   False
# 375940    63306    2369        27            571                   False
# 375941    63716     500        58            135                   False
#
#        Country Code
# 0                US
# 1                US
# 2                US
# 3                US
# 4                US
# 5                US
# 6                US
# 7                US
# 8                US
# 9                US
# 10               US
# 11               US
# 12               US
# 13               US
# 14               US
# 15               US
# 16               US
# 17               US
# 18               US
# 19               US
# 20               US
# 21               US
# 22               US
# 23               US
# 24               US
# 25               US
# 26               US
# 27               US
# 28               US
# 29               US
# ...             ...
# 375910           KR
# 375911           KR
# 375912           KR
# 375913           KR
# 375914           KR
# 375915           KR
# 375916           KR
# 375917           KR
# 375918           KR
# 375919           KR
# 375920           KR
# 375921           KR
# 375922           KR
# 375923           KR
# 375924           KR
# 375925           KR
# 375926           KR
# 375928           KR
# 375929           KR
# 375930           KR
# 375931           KR
# 375933           KR
# 375934           KR
# 375935           KR
# 375936           KR
# 375937           KR
# 375938           KR
# 375939           KR
# 375940           KR
# 375941           KR
#
# [356027 rows x 10 columns]

# %%
#compare number of views to likes/dislikes votes?
#compare number of views to comments?
# How long a video trends to number of views?
#Top Genres?
#Most commented, Most disliked, Most liked, longest trending video, most viewed video?
total_count = len(df["category_id"].unique())
total_count
# Out:
# 18

# %%
#dataframes for each country
US = df.loc[df["Country Code"]=="US"]
MX = df.loc[df["Country Code"]=="MX"]
CA = df.loc[df["Country Code"]=="CA"]
RU = df.loc[df["Country Code"]=="RU"]
DE = df.loc[df["Country Code"]=="DE"]
FR = df.loc[df["Country Code"]=="FR"]
GB = df.loc[df["Country Code"]=="GB"]
IN = df.loc[df["Country Code"]=="IN"]
JP = df.loc[df["Country Code"]=="JP"]
KR = df.loc[df["Country Code"]=="KR"]

# %%
#dataframes created to display country, video_id, views, likes

data_us = US.loc[:,["Country Code", "video_id", "views", "likes", "dislikes", "comment_count"]]
#data_us
data_mx = MX.loc[:,["Country Code", "video_id", "views", "likes", "dislikes"]]
#data_mx

data_ca = CA.loc[:,["Country Code", "video_id", "views", "likes", "dislikes"]]
#data_ca

data_ru = RU.loc[:,["Country Code", "video_id", "views", "likes", "dislikes"]]
#data_ru

data_de = DE.loc[:,["Country Code", "video_id", "views", "likes", "dislikes"]]
#data_de

data_fr = FR.loc[:,["Country Code", "video_id", "views", "likes", "dislikes"]]
#data_fr
 
data_gb = GB.loc[:,["Country Code", "video_id", "views", "likes", "dislikes"]]
#data_gb

data_in = IN.loc[:,["Country Code", "video_id", "views", "likes", "dislikes"]]
#data_in

data_jp = JP.loc[:,["Country Code", "video_id","views", "likes", "dislikes"]]
#data_jp

data_kr = KR.loc[:,["Country Code", "video_id", "views", "likes", "dislikes"]]
#data_kr

# %%
t = "Likes, Dislikes, and comments per Country"
X  = df[['likes','dislikes','comment_count']]


fig, axes= plt.subplots(3, 4)

for i, ax in enumerate(axes.flatten()):
    x = X[i,:]/np.sum(X[i,:])
    ax.pie(x, autopct="%.1f%%", pctdistance=0.9)
    ax.set_title(t.split()[i])

plt.show()

# Data to plot
labels = 'Likes', 'Dislikes', 'Comments'
sizes = [215, 130, 245]
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=120)

plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-3eda2b3c018c> in <module>
#       6
#       7 for i, ax in enumerate(axes.flatten()):
# ----> 8     x = X[i,:]/np.sum(X[i,:])
#       9     ax.pie(x, autopct="%.1f%%", pctdistance=0.9)
#      10     ax.set_title(t.split()[i])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0, slice(None, None, None))' is an invalid key

# %%
#sorted by views to see the highest trending video by country
trending_us = data_us.sort_values("views", axis=0, ascending=False)
trending_us.head()

# %%
# How many likes and dislikes were made out of the total amount of views
likes = (trending_us['views']/trending_us['likes'])
dislikes = (trending_us['views']/trending_us['dislikes'])
view = trending_us['views']

# Create a dataframe with percentages of likes and dislikes, how many views it takes to get one like
comment = trending_us["comment_count"]
total = (trending_us['likes']+trending_us['dislikes'])
percent_likes = (trending_us['likes'] /total) *100
percent_dislikes = (trending_us['dislikes'] /total) *100

# Create a variable for my data frame
percentages_us = {"Views": view, "Comments": comment, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

# data frame coding and printing
percent_data_us = pd.DataFrame(percentages_us)
percent_data_us.head()

# %%
#total likes, dislikes, comments, and views
views_us = data_us["views"]
total_views = views_us.sum(axis=0)

comments_us = data_us["comment_count"]
total_comments = comments_us.sum(axis=0)

dislikes_us = data_us["dislikes"]
total_dislikes = dislikes_us.sum(axis=0)

likes_us = data_us["likes"]
total_likes = likes_us.sum(axis=0)

#Print out the data
print("The US has ",total_likes, "total YouTube Video likes")
print("The US has ",total_dislikes, "total YouTube Video dislikes")
print("The US has ",total_comments, "total YouTube video comments")
print("The US has ",total_views, "total YouTube video views")

# %%
# Data to plot
labels = 'Likes', 'Dislikes', 'Comments'
sizes = [215, 130, 245]
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.1, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=120)

plt.axis('equal')
plt.show()

# %%
trending_mx = data_mx.sort_values("views", axis=0, ascending=False)
trending_mx.head()

# %%
likes = (trending_mx['views']/trending_mx['likes'])

dislikes = (trending_mx['views']/trending_mx['dislikes'])
view = trending_mx['views']

vid_id = trending_mx["video_id"]
total = (trending_mx['likes']+trending_mx['dislikes'])
percent_likes = (trending_mx['likes'] /total) *100
percent_dislikes = (trending_mx['dislikes'] /total) *100

percentages_mx = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data_mx = pd.DataFrame(percentages)
percent_data_mx.head()

# %%
trending_ca = data_ca.sort_values("views", axis=0, ascending=False)
trending_ca.head()

# %%
likes = (trending_ca['views']/trending_ca['likes'])

dislikes = (trending_ca['views']/trending_ca['dislikes'])
view = trending_ca['views']

vid_id = trending_ca["video_id"]
total = (trending_ca['likes']+trending_ca['dislikes'])
percent_likes = (trending_ca['likes'] /total) *100
percent_dislikes = (trending_ca['dislikes'] /total) *100

percentages_ca = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data_ca = pd.DataFrame(percentages)
percent_data_ca.head()

# %%
trending_ru = data_ru.sort_values("views", axis=0, ascending=False)
trending_ru.head()

# %%
likes = (trending_ru['views']/trending_ru['likes'])

dislikes = (trending_ru['views']/trending_ru['dislikes'])
view = trending_ru['views']

vid_id = trending_ru["video_id"]
total = (trending_ru['likes']+trending_ru['dislikes'])
percent_likes = (trending_ru['likes'] /total) *100
percent_dislikes = (trending_ru['dislikes'] /total) *100

percentages = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data = pd.DataFrame(percentages)
percent_data.head()

# %%
trending_de = data_de.sort_values("views", axis=0, ascending=False)
trending_de.head(10)

# %%
likes = (trending_de['views']/trending_de['likes'])
dislikes = (trending_de['views']/trending_de['dislikes'])
view = trending_de['views']

vid_id = trending_de["video_id"]
total = (trending_de['likes']+trending_de['dislikes'])
percent_likes = (trending_de['likes'] /total) *100
percent_dislikes = (trending_de['dislikes'] /total) *100

percentages = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data = pd.DataFrame(percentages)
percent_data.head()

# %%
trending_fr = data_fr.sort_values("views", axis=0, ascending=False)
trending_fr.head(10)

# %%
likes = (trending_fr['views']/trending_fr['likes'])

dislikes = (trending_fr['views']/trending_fr['dislikes'])
view = trending_fr['views']

vid_id = trending_fr["video_id"]
total = (trending_fr['likes']+trending_fr['dislikes'])
percent_likes = (trending_fr['likes'] /total) *100
percent_dislikes = (trending_fr['dislikes'] /total) *100

percentages = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data = pd.DataFrame(percentages)
percent_data.head()

# %%
trending_gb = data_gb.sort_values("views", axis=0, ascending=False)
trending_gb.head(10)

# %%
likes = (trending_gb['views']/trending_gb['likes'])

dislikes = (trending_gb['views']/trending_gb['dislikes'])
view = trending_gb['views']


vid_id = trending_gb["video_id"]
total = (trending_gb['likes']+trending_gb['dislikes'])
percent_likes = (trending_gb['likes'] /total) *100
percent_dislikes = (trending_gb['dislikes'] /total) *100

percentages = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data = pd.DataFrame(percentages)
percent_data.head()

# %%
trending_in = data_in.sort_values("views", axis=0, ascending=False)
trending_in.head(10)

# %%
likes = (trending_in['views']/trending_in['likes'])

dislikes = (trending_in['views']/trending_in['dislikes'])
view = trending_in['views']

vid_id = trending_in["video_id"]
total = (trending_in['likes']+trending_in['dislikes'])
percent_likes = (trending_in['likes'] /total) *100
percent_dislikes = (trending_in['dislikes'] /total) *100

percentages = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data = pd.DataFrame(percentages)
percent_data.head()

# %%
trending_jp = data_jp.sort_values("views", axis=0, ascending=False)
trending_jp.head(10)

# %%
likes = (trending_jp['views']/trending_jp['likes'])

dislikes = (trending_jp['views']/trending_jp['dislikes'])
view = trending_jp['views']

vid_id = trending_jp["video_id"]
total = (trending_jp['likes']+trending_jp['dislikes'])
percent_likes = (trending_jp['likes'] /total) *100
percent_dislikes = (trending_jp['dislikes'] /total) *100

percentages = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data = pd.DataFrame(percentages)
percent_data.head()

# %%
trending_kr = data_kr.sort_values("views", axis=0, ascending=False)
trending_kr.head(10)

# %%
likes = (trending_kr['views']/trending_kr['likes'])

dislikes = (trending_kr['views']/trending_kr['dislikes'])
view = trending_kr['views']

vid_id = trending_kr["video_id"]
total = (trending_kr['likes']+trending_kr['dislikes'])
percent_likes = (trending_kr['likes'] /total) *100
percent_dislikes = (trending_kr['dislikes'] /total) *100

percentages = {"Vid Id": vid_id, "Views": view, "Views per like": likes, "Views per dislike": dislikes, "Percent of Likes": percent_likes,
               "Percent of Dislikes": percent_dislikes }

percent_data = pd.DataFrame(percentages)
percent_data.head()
